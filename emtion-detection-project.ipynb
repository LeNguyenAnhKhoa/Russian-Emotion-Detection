# %%
import sys
sys.path.append('/kaggle/input/rus-model/Emotion Detection Kaggle')
import json, torch
from LoadData import load_dataset
from Model import Model
from EmotionDataset import EmotionDataset
from train import train
from plot import plot
from predict import predict
from sklearn.model_selection import KFold
import numpy as np
from analyze import analyze

# %%
with open("/kaggle/input/rus-model/Emotion Detection Kaggle/config.json", "r") as file:
    config = json.load(file)
batch_size = config["batch_size"]
train_path = config["train_path"]
test_path = config["test_path"]
learning_rate = config["learning_rate"]
base_model = config["base_model"]
num_labels = config["num_labels"]
problem_type = config["problem_type"]
labels = config["LABELS"]
num_epoch = config["num_epoch"]
eps = config["eps"]
th = config["th"]
random_state = config["random_state"]
n_splits = config["n_splits"]
Min_loss = config["Min_loss"]
num_folds = config["num_fold"]

# %%
X, y, X_test, test_df = load_dataset(train_path, test_path)
kfold = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

# %%
from sklearn.metrics import f1_score
def find_threshold(model, valid_loader):
    device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu') 
    for th in np.arange(0.2, 0.7, 0.01):
        f1score_sum = 0
        for batch in valid_loader:
            batch = {k: v.to(device) for k, v in batch.items() if k != "text"}
            with torch.no_grad():
                outputs = model(**batch)
            logits = outputs.logits
            predictions = np.array(torch.sigmoid(logits).tolist())
            predictions = np.where(predictions > th, 1, 0)
            label = batch["labels"].cpu().numpy()
            f1score_sum += f1_score(label, predictions, average='macro', zero_division=1)
            
        f1score_avg = (f1score_sum / len(valid_loader)).item()
        print(f"threshold = {th:.3f}   -   f1-score = {f1score_avg:.5f}")

# %%
best_models = [] 
fold_valid_losses = [] 
wrong_predcit = []

for fold, (train_idx, val_idx) in enumerate(kfold.split(X)):
    X_train, X_valid = X[train_idx].tolist(), X[val_idx].tolist()
    y_train, y_valid = y[train_idx].tolist(), y[val_idx].tolist()
    model, tokenizer = Model(base_model, num_labels, problem_type, labels).build()
    train_loader, valid_loader, test_loader = EmotionDataset(tokenizer, batch_size).build_dataset(X_train, y_train, X_valid, y_valid, X_test)

    optimizer = torch.optim.AdamW(model.parameters(), lr = learning_rate, betas = (0.9, 0.98), eps = eps, weight_decay=0.01)
    model, train_losses, valid_losses, train_f1scores, valid_f1scores = train(num_epoch, model, train_loader, valid_loader, optimizer, th, Min_loss)
    wrong_predcit.append(analyze(model, valid_loader, th))
    #find_threshold(model, valid_loader)
    #plot(train_losses, valid_losses, "loss", "Loss training and valid curve", num_epoch)
    #plot(train_f1scores, valid_f1scores, "F1-score", "F1-score training and valid", num_epoch)
    
    Min_valid_loss = valid_losses[-1]
    fold_valid_losses.append(Min_valid_loss)

    if Min_valid_loss < Min_loss:
        model_save_path = f'model_fold_{fold + 1}_loss_{Min_valid_loss:.4f}.pt'
        torch.save({
            'fold': fold + 1,
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),
            'valid_loss': Min_valid_loss,
            'train_losses': train_losses,
            'valid_losses': valid_losses,
            'train_f1scores': train_f1scores,
            'valid_f1scores': valid_f1scores
        }, model_save_path)
        best_models.append({
            'fold': fold + 1,
            'model': model,
            'loss': Min_valid_loss,
            'path': model_save_path
        })
        print(f"Saved model for fold {fold + 1} with validation loss: {Min_valid_loss:.4f}\n\n\n")
    if fold == num_folds-1:
        break
# Out:
# tokenizer_config.json:   0%|          | 0.00/373 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# config.json:   0%|          | 0.00
# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
wrong_predcit[0]
# Out:
#                                                                                                                             text  \
# 0                                                               всё так я тоже впечатлен поведением укр церкви в текущей ситуаци
# 1                                                                                            Да блин ! Ну Детка ты должна зажечь
# 2                                                                                     чувствую новый год будет полнейшим дерьмом
# 3                                         о боже мой даже не верится что прошел уже целый год с тех пор как ничего не изменилось
# 4                                                    И дана улице просто пиздец Такой ветерчто мне кажется мою пятиэтажку унесет
# 5                                                                                                        Завтра к третьему уроку
# 6                                                                        Как вы со мной общаетесь ? На меня же смотреть противно
# 7   Смотрю повтор речи Чернышенко это конечно ужас тербл я так говорил на инглише когда мне было 10 ! Олимпиада Мутко английский
# 8                                                                                             Черепаха клаустрофоб живёт в ужасе
# 9                 Здоровый крепкий сон это когда ставишь будильник на повтор через каждые 5 минут и каждый раз успеваешь заснуть
# 10                                                                Зашла в твитер а у меня счетчики по нулям Перепугалась сюрприз
# 11                                                                                                     Эта работа меня убивает !
# 12           я так хочу плакать ужасно хочу плакать ненавижу такой немецкий который будет завтра и я устала я все сказала грусть
# 13                                                                                     Отвратительный день Все в школе как зомби
# 14                                                                                     Объясните зачем ставить себя на шапку бля
# 15                                    yuri Караул ! США обесчестили росийских дипломатов уличив их в мошеничестве с медицинскими
# 16                                    В этом учебном году все поменялось местамиперевернулосьвсе совершено по другому ! Дурдом !
# 17                                                                                                          ахах я не одна такая
# 18                                                                Играю в GTA по онлайн на сервере samp rp Мой ник Slava Ramires
#
#                                           different_emotions
# 0                             [surprise: predict=0, label=1]
# 1       [anger: predict=1, label=0, joy: predict=0, label=1]
# 2                              [disgust: predict=1, label=0]
# 3                                  [joy: predict=1, label=0]
# 4                                 [fear: predict=0, label=1]
# 5                                  [joy: predict=0, label=1]
# 6                             [surprise: predict=0, label=1]
# 7    [disgust: predict=0, label=1, fear: predict=1, label=0]
# 8                                 [fear: predict=1, label=0]
# 9                                  [joy: predict=1, label=0]
# 10  [fear: predict=0, label=1, surprise: predict=1, label=0]
# 11                             [sadness: predict=0, label=1]
# 12                               [anger: predict=1, label=0]
# 13  [anger: predict=0, label=1, sadness: predict=1, label=0]
# 14                            [surprise: predict=0, label=1]
# 15                                [fear: predict=0, label=1]
# 16      [anger: predict=0, label=1, joy: predict=1, label=0]
# 17                            [surprise: predict=1, label=0]
# 18                                 [joy: predict=1, label=0]

# %%
wrong_predcit[1]
# Out:
#                                                                                                                                    text  \
# 0                                                                                  Юна ты всё больше удивляешь меня своими достижениями
# 1                                                                       Людиотличная новость 47 школы закрыли на карантин краснокаменск
# 2                                                                                                  Вот Рима коза ! не проверила тесты !
# 3                                                                                              Мда уж Дрожащими руками пишу бля радость
# 4                                                                                                           о боже Аля Киркоров радость
# 5                                              Теракт на вокзале в Волгограде По предварительным даным не мене 18 человек погибли Жесть
# 6                                                                                                                  Пить одеколон ужасно
# 7                                                                                            Учимся 31 декабря провал этоненорма пиздец
# 8             Мне приснился сегодня Курт Кобейн И я теперь как то ошарашена Он сказал мне такое над чем мне реально пришлось задуматься
# 9                                                                                                                             Воу круто
# 10  Девушкикак можно требовать что то от парня ? Если он захочет сделать вам подарокто он сделает ! Че выпрашивать то ? Фуотвратительно
# 11                                                                                                                У меня головасукболит
# 12                                                если честномне начинает это надоедать понимаючто отвыклано больше не хочу это терпеть
# 13                                                                                Дрожу как осиновый лист когда смотрю в дверной глазок
# 14                                        меня даже мать перестала целоватьпотому что говорит что я отвратительна спасибомам люблю тебя
# 15                                Сознание Нестин пока самая мерзкая штука которую я видела в олдскуле Эти щупальца боже правый сюрприз
# 16                                                                      сейчас я могу писать только твиты о том как же меня все заебало
# 17                                Капец она идиотка пишет что клип дерьмо исполня в нем главную роль ! Может он иза не все таки такой ?
# 18                                                                                                              ПОТОМУ ЧТО ТЫ ОФИГЕЛА !
# 19                                                             Погода тоже сука гавно настроение хуйня ебаное еще и сигареты подорожали
# 20                             Ахахах люблю тебя радость Меня скоро болезнь убьет Две недели назад выздоровела и снова приболела грусть
#
#                                                                        different_emotions
# 0                                                               [joy: predict=0, label=1]
# 1                                                          [surprise: predict=1, label=0]
# 2      [anger: predict=0, label=1, joy: predict=1, label=0, surprise: predict=1, label=0]
# 3                                     [fear: predict=0, label=1, joy: predict=1, label=0]
# 4                                                               [joy: predict=1, label=0]
# 5   [fear: predict=0, label=1, sadness: predict=0, label=1, surprise: predict=1, label=0]
# 6                                                           [sadness: predict=1, label=0]
# 7                                [anger: predict=0, label=1, sadness: predict=1, label=0]
# 8                                                          [surprise: predict=0, label=1]
# 9                                                               [joy: predict=0, label=1]
# 10                              [anger: predict=1, label=0, surprise: predict=1, label=0]
# 11                               [anger: predict=0, label=1, sadness: predict=1, label=0]
# 12  [anger: predict=0, label=1, disgust: predict=1, label=0, sadness: predict=1, label=0]
# 13                                                             [fear: predict=0, label=1]
# 14                                                          [disgust: predict=1, label=0]
# 15                                                            [anger: predict=0, label=1]
# 16                                                          [sadness: predict=1, label=0]
# 17                            [disgust: predict=1, label=0, surprise: predict=1, label=0]
# 18                                                         [surprise: predict=1, label=0]
# 19                                                          [sadness: predict=1, label=0]
# 20                                                              [joy: predict=0, label=1]

# %%
wrong_predcit[2]
# Out:
#                                                                                                                   text  \
# 0                             отвратительно когда люди просто без причины забывают старых друзей переключаясь на новых
# 1                                                                                                              Тигруля
# 2   О Боже ж ты мой ! Я и не заметила что последний твит был 1000 ! Ну что ж смело перешагиваю эту цифру и 1001 твит !
# 3                                                                                                                вау !
# 4                                                                                                         Вот дерьмо !
# 5                                                                                       ты мерзкийкак весь мир мерзкий
# 6                                                                                                      Бля убейте меня
# 7                                             Просочившаяся из под двери вонь быстро распространилась по всему зДаниию
# 8                                          Мама наказала так что теперь не гулять не телефона ! Короче полный пиздец !
# 9                                                                     ДЕЛО Владельцы Nokia Lumia могут создавать папки
# 10                                                                           И так страшно было еще и настроение упало
# 11                                                как так ? приезжала и не увиделись грусть я скучаю по тебе малышка !
# 12                                       Кажется лицо сводит судорогой отвращения и презрения А всего то из дома вышла
# 13                                                                                                            боже мой
# 14                              ебнутые ибо они там и на своих териториях устраивают зачистки им много поводов не надо
# 15                                                                      так а хули мне не исправили двойки по физике ?
# 16                     Через 30 минут идти к репетитору не сделал 4 заДаниия Пишу твиты и общаюсь с лисицей Мне пиздец
# 17                                                                 моя успеваемость по предметам доводит меня до ужаса
# 18                                        обидно и за нашу странукоторую оскверняют и показывают как какого то монстра
# 19         И как завтра ехать на встречуесли центр перекрыт Росияне выебывайся со своим факелом ОЛИМПИАДА екатеринбург
# 20          На 70 балов написала английский О по моему слишком много для меня вот бы так на самом ЕГЭ написать радость
# 21                  как же мне противно читать эти ваши то чувство когда меньше 10 ретвитов за день картинка фэйспалма
# 22                                                      Честно говоря чувствую себя дерьмом что самой от себя противно
# 23                                                                                        Мдане ожидала от тебя такого
# 24                                                  ФУ иди переоденься мамбетка Голову помой и еще слой тоналки сделай
# 25                                                                              Сижу завтракуюи тут снег пошёл радость
# 26                                                             Это омерзительное чувство когда тебя укачивает в машине
# 27                                                                                                 Мы приготовили борщ
# 28                                                                              ЧТО ВЫ РАЗВЕЛИ НА ИНСТЕ ДЖА ?! ПОЗОР !
#
#                                             different_emotions
# 0     [anger: predict=0, label=1, sadness: predict=1, label=0]
# 1                                    [joy: predict=0, label=1]
# 2                                    [joy: predict=1, label=0]
# 3                                    [joy: predict=0, label=1]
# 4   [disgust: predict=1, label=0, sadness: predict=0, label=1]
# 5                                  [anger: predict=1, label=0]
# 6        [anger: predict=0, label=1, fear: predict=1, label=0]
# 7      [disgust: predict=0, label=1, fear: predict=1, label=0]
# 8                                  [anger: predict=1, label=0]
# 9                                    [joy: predict=1, label=0]
# 10                               [sadness: predict=0, label=1]
# 11                              [surprise: predict=0, label=1]
# 12                                 [anger: predict=1, label=0]
# 13                              [surprise: predict=0, label=1]
# 14                               [disgust: predict=0, label=1]
# 15                              [surprise: predict=1, label=0]
# 16     [fear: predict=0, label=1, sadness: predict=1, label=0]
# 17       [anger: predict=1, label=0, fear: predict=0, label=1]
# 18                               [disgust: predict=1, label=0]
# 19                              [surprise: predict=0, label=1]
# 20                              [surprise: predict=0, label=1]
# 21                                 [anger: predict=1, label=0]
# 22                               [sadness: predict=0, label=1]
# 23                               [sadness: predict=1, label=0]
# 24    [anger: predict=1, label=0, disgust: predict=0, label=1]
# 25                              [surprise: predict=0, label=1]
# 26                               [sadness: predict=1, label=0]
# 27                                   [joy: predict=1, label=0]
# 28                               [disgust: predict=1, label=0]

# %%
wrong_predcit[3]
# Out:
#                                                                                                                                       text  \
# 0                                                      Надоело уже быть крошкой и маденьким солнышком Я не настолько младше тебя смущенный
# 1                                               Планы могут меняться и к лучшему так ? Утомительные поиски приводят к цели рано или поздно
# 2                                           кстативсе равно мы молодцы ! наша группа заняла второе место в олимпиаде пиздюки первые грусть
# 3                                                                                    люди такие добрые ! я просто поражаюсь реально добрые
# 4                                                     ух даже не верится что я предыдущий твит не редактируя сразу в 140 символов уместила
# 5                            Стойкое ощущение что кроме шлюхи ничего дельного из меня не выйдет шлюха пиздец конец безысходность тлен боль
# 6                                                                    не спала всю ночь:о теперь как зомби пиздец зомби апокалипсис недосып
# 7                                                                У меня одной появляется отвращение к человеку который пишет не грамотно ?
# 8                          ух ты что я нашла радость чуть меньше года назад написала заметку об одной компани и вот теперь я в ней работаю
# 9                                                                           Как же невозможно жить в этом мире лжи ненависти и боли грусть
# 10                                                                                                          завтра не день а пиздец просто
# 11                                          ну вот вконтакте прекратил работать ! и как мне слушать ту музыкукоторую я не скачала ? пиздец
# 12                                                                           Убейте меня ! Работать в суботу утром да как же тяжело грусть
# 13                                                              Это неловкое чувство когда все давят на тебя и всем насрать на твое мнение
# 14                                                                  видел красную телефоную будку в Костромебудто побывал в Лондоне щастье
# 15                                                                                 Побил свой же рекорд ! Ахуеть ! 214 980 ! ебатьколотить
# 16                                                           Завтра здаю зачёт по истори 7 страниц исписала и это ещё не всё конецчетверти
# 17                                                                      Это просто пиздец ! я приебал в эту школу к 8 а нам блять к 9 Клас
# 18                                                                                Жена пенсионерка Шаляпина поразила меня фигурой в бикини
# 19   хотели с братом посмотреть мульт и блятьКОГДА МЫ ПОПРОСИЛИ ЖЁСТКИЙ ДИСКМОЯ ТЁТЯ СКАЗАЛА ЧТО ТАМ ПОРНО И НЕ РАЗРЕШИЛА ЕГО БРАТЬ пиздец
# 20  у меня сейчас трясутся руки и кружится голова я не верю что совсем скоро увижу выступление Ли боже я в раю и не хочу чтобы он кончался
# 21                                                                                                              какое то дерьмо получается
# 22                                                                     безумно сложно исправлять ебаные оценки ! устала пиздец ебанаяшкола
# 23                                                                                                                        вечерние милости
# 24                                                                Ну привет мерзкий премерзкий город ненаписаная курсовая и прочая гадость
# 25                                                                                                             Как можно быть таким козлом
#
#                                                                        different_emotions
# 0                                                           [disgust: predict=1, label=0]
# 1                                                          [surprise: predict=1, label=0]
# 2                                  [joy: predict=0, label=1, sadness: predict=1, label=0]
# 3                                                               [joy: predict=1, label=0]
# 4                                                               [joy: predict=0, label=1]
# 5                                                              [fear: predict=0, label=1]
# 6                                [anger: predict=1, label=0, sadness: predict=0, label=1]
# 7                                [anger: predict=1, label=0, disgust: predict=0, label=1]
# 8                                                               [joy: predict=0, label=1]
# 9                                                           [disgust: predict=1, label=0]
# 10                                [fear: predict=0, label=1, sadness: predict=1, label=0]
# 11                            [sadness: predict=0, label=1, surprise: predict=1, label=0]
# 12                                                            [anger: predict=1, label=0]
# 13  [anger: predict=1, label=0, disgust: predict=1, label=0, sadness: predict=0, label=1]
# 14                                [joy: predict=0, label=1, surprise: predict=1, label=0]
# 15                                                         [surprise: predict=1, label=0]
# 16                                                          [sadness: predict=0, label=1]
# 17                                                         [surprise: predict=0, label=1]
# 18                                                              [joy: predict=1, label=0]
# 19                                                         [surprise: predict=0, label=1]
# 20                                    [fear: predict=1, label=0, joy: predict=0, label=1]
# 21                                                          [disgust: predict=0, label=1]
# 22                                                          [sadness: predict=0, label=1]
# 23                                                              [joy: predict=0, label=1]
# 24                               [anger: predict=1, label=0, sadness: predict=0, label=1]
# 25                            [disgust: predict=1, label=0, surprise: predict=0, label=1]

# %%
wrong_predcit[4]
# Out:
#                                                                                                                                                      text  \
# 0                                                                                                              Мысль о смерти страшне смерти читаювзаимно
# 1                                                   Не слушайте тех кто хорошо о вас отзывается Вы как были ничтожными кусками говна так ими и останетесь
# 2   Эх сегодня прекрасная погода ! На улице 10 ! я в шоке но вобще круто радость иду себе наушники напялила и иду рэп слушаю радость незабываемое чувство
# 3                                                                                                          Что бы ни происходило все хорошо Мудрость Дзен
# 4                                                                                    отвратный диджей в фокс кафе у меня ужасно болят уши от быдло музыки
# 5                                                                                                                         Пиздец в хорошем смысле ! Голос
# 6                                                                                                                                      В шоке от погоды !
# 7                                                            Я вобще в шоке ! Как можно выпрашивать чтобы за тобой ухаживали и делали романтики ? радость
# 8                                                                                                                        Офигеть на улице как будто весна
# 9                                                                   Самое ужасноеэто выход на работу раньше времени честное слово я устала от всего этого
# 10                                                 За 5 недель нога под гипсом не чесалась ни разу и вот сейчас в очереди в регистратуру так дико зудит !
# 11                                                                                                                                              БИРЮЗОВЫЙ
# 12                                                                                                Меня обслуживает пьяная девушка в ювелирке Какой кошмар
# 13                                                                                              некоторые страные личности не перестают удивлять до гнева
# 14                                                                                          Ещё нет четырёх часов а я уже сделала уроки Страно и гордость
# 15                                                                                                          вырвалось тройка бля по с р ненавижу БИОЛОГИЮ
# 16                                                    Единственое что меня радует в это гнусное утро кофе И мысль о том что я приду со школы и буду спать
# 17                                                                                  Свали же ты уже чмо грузинское говнодень убейте Виталия МожноМнеВесну
# 18                                                                                                                               как всегда хуйни зададут
#
#                                          different_emotions
# 0                                [fear: predict=0, label=1]
# 1                             [disgust: predict=0, label=1]
# 2                            [surprise: predict=0, label=1]
# 3    [joy: predict=0, label=1, sadness: predict=1, label=0]
# 4                               [anger: predict=0, label=1]
# 5    [joy: predict=0, label=1, sadness: predict=1, label=0]
# 6                               [anger: predict=0, label=1]
# 7                             [disgust: predict=0, label=1]
# 8                                 [joy: predict=0, label=1]
# 9                               [anger: predict=1, label=0]
# 10                            [disgust: predict=1, label=0]
# 11                                [joy: predict=1, label=0]
# 12  [disgust: predict=0, label=1, fear: predict=1, label=0]
# 13                              [anger: predict=0, label=1]
# 14                           [surprise: predict=0, label=1]
# 15                            [disgust: predict=0, label=1]
# 16   [joy: predict=1, label=0, sadness: predict=0, label=1]
# 17                            [disgust: predict=0, label=1]
# 18                            [sadness: predict=1, label=0]

# %%
if best_models:
    best_model = min(best_models, key=lambda x: x['loss']) 
    print(f"\nUsing best model from fold {best_model['fold']} for prediction (loss: {best_model['loss']:.4f})")
    predict(best_model['model'], test_loader, test_df, 0.43)
else:
    print("\nNo models met the minimum loss criterion. Using the last trained model for prediction.")
    predict(model, test_loader, test_df, th)
# Out:
# No models met the minimum loss criterion. Using the last trained model for prediction.
